# %%
# Imports
from tira.third_party_integrations import ensure_pyterrier_is_loaded, persist_and_normalize_run
from tira.rest_api_client import Client
import pyterrier as pt
import pandas as pd

# %%
# Create a REST client to the TIRA platform for retrieving the pre-indexed data.
ensure_pyterrier_is_loaded()
tira = Client()

# %%
# The dataset: the union of the IR Anthology and the ACL Anthology
# This line creates an IRDSDataset object and registers it under the name provided as an argument.
pt_dataset = pt.get_dataset('irds:ir-lab-sose-2024/ir-acl-anthology-20240504-training')
pt_dataset.get_topics('query').head(4)
# Out:
#   qid                                     query
# 0   1  retrieval system improving effectiveness
# 1   2  machine learning language identification
# 2   3             social media detect self harm
# 3   4             stemming for arabic languages

# %%
# This assumes we have execited the ../baseline-retrieval-system/baseline-retrieval-system.ipynb notebook before.
bm25 = pt.io.read_results('../runs/runbm25.txt')
ngrams = pt.io.read_results('../runs/runngram.txt')
pt.Experiment(
    [bm25, ngrams],
    pt_dataset.get_topics(),
    pt_dataset.get_qrels(),
    ["ndcg_cut.10", "recip_rank", "recall_1000", "map"],
    names=["BM25", "Ngrams"]
)
# Out:
# There are multiple query fields available: ('text', 'title', 'query', 'description', 'narrative'). To use with pyterrier, provide variant or modify dataframe to add query column.
#      name  ndcg_cut.10  recip_rank  recall_1000       map
# 0    BM25     0.374041    0.579877     0.825376  0.262311
# 1  Ngrams     0.323783    0.589506     0.701347  0.202929

# %%
# This assumes we have execited the ../baseline-retrieval-system/baseline-retrieval-system.ipynb notebook before.
bm25 = pt.io.read_results('../runs/runbm25.txt')
ngrams = pt.io.read_results('../runs/runngram.txt')
res_dict = pt.Experiment(
    [bm25, ngrams],
    pt_dataset.get_topics(),
    pt_dataset.get_qrels(),
    ["ndcg_cut.10", "recip_rank", "recall_1000", "map"],
    names=["BM25", "Ngrams"],
    #baseline=0,
    perquery = True,
    save_dir = "./",
    save_mode="overwrite",
    dataframe = True
)
print(res_dict)
# Out:
# There are multiple query fields available: ('text', 'title', 'query', 'description', 'narrative'). To use with pyterrier, provide variant or modify dataframe to add query column.
#        name qid      measure     value
# 0      BM25   1          map  0.404455
# 1      BM25   1   recip_rank  1.000000
# 2      BM25   1  recall_1000  0.966667
# 3      BM25   1  ndcg_cut.10  0.835780
# 36     BM25  10          map  0.001188
# ..      ...  ..          ...       ...
# 303  Ngrams   8  ndcg_cut.10  0.000000
# 304  Ngrams   9          map  0.147781
# 305  Ngrams   9   recip_rank  0.200000
# 306  Ngrams   9  recall_1000  1.000000
# 307  Ngrams   9  ndcg_cut.10  0.090928
#
# [544 rows x 4 columns]

# %%
import pandas as pd
df = pd.DataFrame(res_dict)
print(df)
# Filter criteria
filter_criteria = (
    (df['measure'] == 'map') &
    (df['name'].isin(['Ngrams', 'BM25']))
)

# Apply the filter
filtered_df = df[filter_criteria]

# Group by 'qid' and filter groups that have both 'NGRAMS' and 'BM25' entries
groups = filtered_df.groupby('qid')
valid_pairs = []
valid_qids = []
for qid, group in groups:
    if len(group) == 2 and set(group['name']) == {'Ngrams', 'BM25'}:
        ngrams_row = group[group['name'] == 'Ngrams'].iloc[0]
        bm25_row = group[group['name'] == 'BM25'].iloc[0]
        
        if ngrams_row['value'] > bm25_row['value']:
            valid_pairs.append((ngrams_row, bm25_row))
            valid_qids.append(qid)
# Print the valid pairs
for ngrams_row, bm25_row in valid_pairs:
    print(f"Pair found for qid {ngrams_row['qid']}:")
    print(f"Ngrams: {ngrams_row}")
    print(f"BM25: {bm25_row}")
    print(valid_qids)
# Out:
#        name qid      measure     value
# 0      BM25   1          map  0.404455
# 1      BM25   1   recip_rank  1.000000
# 2      BM25   1  recall_1000  0.966667
# 3      BM25   1  ndcg_cut.10  0.835780
# 36     BM25  10          map  0.001188
# ..      ...  ..          ...       ...
# 303  Ngrams   8  ndcg_cut.10  0.000000
# 304  Ngrams   9          map  0.147781
# 305  Ngrams   9   recip_rank  0.200000
# 306  Ngrams   9  recall_1000  1.000000
# 307  Ngrams   9  ndcg_cut.10  0.090928
#
# [544 rows x 4 columns]
# Pair found for qid 11:
# Ngrams: name         Ngrams
# qid              11
# measure         map
# value      0.351688
# Name: 312, dtype: object
# BM25: name           BM25
# qid              11
# measure         map
# value      0.327284
# Name: 40, dtype: object
# ['11', '18', '19', '2', '20', '24', '25', '26', '27', '3', '31', '39', '40', '49', '50', '54', '55', '56', '57', '65', '66', '67', '9']
# Pair found for qid 18:
# Ngrams: name         Ngrams
# qid              18
# measure         map
# value      0.207559
# Name: 340, dtype: object
# BM25: name           BM25
# qid              18
# measure         map
# value      0.202273
# Name: 68, dtype: object
# ['11', '18', '19', '2', '20', '24', '25', '26', '27', '3', '31', '39', '40', '49', '50', '54', '55', '56', '57', '65', '66', '67', '9']
# Pair found for qid 19:
# Ngrams: name         Ngrams
# qid              19
# measure         map
# value      0.322845
# Name: 344, dtype: object
# BM25: name          BM25
# qid             19
# measure        map
# value      0.29417
# Name: 72, dtype: object
# ['11', '18', '19', '2', '20', '24', '25', '26', '27', '3', '31', '39', '40', '49', '50', '54', '55', '56', '57', '65', '66', '67', '9']
# Pair found for qid 2:
# Ngrams: name         Ngrams
# qid               2
# measure         map
# value      0.293501
# Name: 276, dtype: object
# BM25: name           BM25
# qid               2
# measure         map
# value      0.161474
# Name: 4, dtype: object
# ['11', '18', '19', '2', '20', '24', '25', '26', '27', '3', '31', '39', '40', '49', '50', '54', '55', '56', '57', '65', '66', '67', '9']
# Pair found for qid 20:
# Ngrams: name         Ngrams
# qid              20
# measure         map
# value      0.263567
# Name: 348, dtype: object
# BM25: name           BM25
# qid              20
# measure         map
# value      0.098117
# Name: 76, dtype: object
# ['11', '18', '19', '2', '20', '24', '25', '26', '27', '3', '31', '39', '40', '49', '50', '54', '55', '56', '57', '65', '66', '67', '9']
# Pair found for qid 24:
# Ngrams: name         Ngrams
# qid              24
# measure         map
# value      0.435881
# Name: 364, dtype: object
# BM25: name           BM25
# qid              24
# measure         map
# value      0.376144
# Name: 92, dtype: object
# ['11', '18', '19', '2', '20', '24', '25', '26', '27', '3', '31', '39', '40', '49', '50', '54', '55', '56', '57', '65', '66', '67', '9']
# Pair found for qid 25:
# Ngrams: name         Ngrams
# qid              25
# measure         map
# value      0.150642
# Name: 368, dtype: object
# BM25: name           BM25
# qid              25
# measure         map
# value      0.135211
# Name: 96, dtype: object
# ['11', '18', '19', '2', '20', '24', '25', '26', '27', '3', '31', '39', '40', '49', '50', '54', '55', '56', '57', '65', '66', '67', '9']
# Pair found for qid 26:
# Ngrams: name         Ngrams
# qid              26
# measure         map
# value      0.067561
# Name: 372, dtype: object
# BM25: name           BM25
# qid              26
# measure         map
# value      0.044366
# Name: 100, dtype: object
# ['11', '18', '19', '2', '20', '24', '25', '26', '27', '3', '31', '39', '40', '49', '50', '54', '55', '56', '57', '65', '66', '67', '9']
# Pair found for qid 27:
# Ngrams: name        Ngrams
# qid             27
# measure        map
# value      0.52293
# Name: 376, dtype: object
# BM25: name           BM25
# qid              27
# measure         map
# value      0.415964
# Name: 104, dtype: object
# ['11', '18', '19', '2', '20', '24', '25', '26', '27', '3', '31', '39', '40', '49', '50', '54', '55', '56', '57', '65', '66', '67', '9']
# Pair found for qid 3:
# Ngrams: name         Ngrams
# qid               3
# measure         map
# value      0.747392
# Name: 280, dtype: object
# BM25: name           BM25
# qid               3
# measure         map
# value      0.698419
# Name: 8, dtype: object
# ['11', '18', '19', '2', '20', '24', '25', '26', '27', '3', '31', '39', '40', '49', '50', '54', '55', '56', '57', '65', '66', '67', '9']
# Pair found for qid 31:
# Ngrams: name         Ngrams
# qid              31
# measure         map
# value      0.265897
# Name: 392, dtype: object
# BM25: name           BM25
# qid              31
# measure         map
# value      0.257956
# Name: 120, dtype: object
# ['11', '18', '19', '2', '20', '24', '25', '26', '27', '3', '31', '39', '40', '49', '50', '54', '55', '56', '57', '65', '66', '67', '9']
# Pair found for qid 39:
# Ngrams: name         Ngrams
# qid              39
# measure         map
# value      0.295825
# Name: 424, dtype: object
# BM25: name           BM25
# qid              39
# measure         map
# value      0.128595
# Name: 152, dtype: object
# ['11', '18', '19', '2', '20', '24', '25', '26', '27', '3', '31', '39', '40', '49', '50', '54', '55', '56', '57', '65', '66', '67', '9']
# Pair found for qid 40:
# Ngrams: name         Ngrams
# qid              40
# measure         map
# value      0.430392
# Name: 428, dtype: object
# BM25: name           BM25
# qid              40
# measure         map
# value      0.304337
# Name: 156, dtype: object
# ['11', '18', '19', '2', '20', '24', '25', '26', '27', '3', '31', '39', '40', '49', '50', '54', '55', '56', '57', '65', '66', '67', '9']
# Pair found for qid 49:
# Ngrams: name         Ngrams
# qid              49
# measure         map
# value      0.100491
# Name: 464, dtype: object
# BM25: name         BM25
# qid            49
# measure       map
# value      0.0969
# Name: 192, dtype: object
# ['11', '18', '19', '2', '20', '24', '25', '26', '27', '3', '31', '39', '40', '49', '50', '54', '55', '56', '57', '65', '66', '67', '9']
# Pair found for qid 50:
# Ngrams: name         Ngrams
# qid              50
# measure         map
# value      0.524457
# Name: 468, dtype: object
# BM25: name           BM25
# qid              50
# measure         map
# value      0.445871
# Name: 196, dtype: object
# ['11', '18', '19', '2', '20', '24', '25', '26', '27', '3', '31', '39', '40', '49', '50', '54', '55', '56', '57', '65', '66', '67', '9']
# Pair found for qid 54:
# Ngrams: name         Ngrams
# qid              54
# measure         map
# value      0.220372
# Name: 484, dtype: object
# BM25: name           BM25
# qid              54
# measure         map
# value      0.208182
# Name: 212, dtype: object
# ['11', '18', '19', '2', '20', '24', '25', '26', '27', '3', '31', '39', '40', '49', '50', '54', '55', '56', '57', '65', '66', '67', '9']
# Pair found for qid 55:
# Ngrams: name        Ngrams
# qid             55
# measure        map
# value      0.49524
# Name: 488, dtype: object
# BM25: name          BM25
# qid             55
# measure        map
# value      0.36879
# Name: 216, dtype: object
# ['11', '18', '19', '2', '20', '24', '25', '26', '27', '3', '31', '39', '40', '49', '50', '54', '55', '56', '57', '65', '66', '67', '9']
# Pair found for qid 56:
# Ngrams: name         Ngrams
# qid              56
# measure         map
# value      0.025076
# Name: 492, dtype: object
# BM25: name           BM25
# qid              56
# measure         map
# value      0.008483
# Name: 220, dtype: object
# ['11', '18', '19', '2', '20', '24', '25', '26', '27', '3', '31', '39', '40', '49', '50', '54', '55', '56', '57', '65', '66', '67', '9']
# Pair found for qid 57:
# Ngrams: name         Ngrams
# qid              57
# measure         map
# value      0.162817
# Name: 496, dtype: object
# BM25: name           BM25
# qid              57
# measure         map
# value      0.134253
# Name: 224, dtype: object
# ['11', '18', '19', '2', '20', '24', '25', '26', '27', '3', '31', '39', '40', '49', '50', '54', '55', '56', '57', '65', '66', '67', '9']
# Pair found for qid 65:
# Ngrams: name         Ngrams
# qid              65
# measure         map
# value      0.122645
# Name: 528, dtype: object
# BM25: name           BM25
# qid              65
# measure         map
# value      0.000913
# Name: 256, dtype: object
# ['11', '18', '19', '2', '20', '24', '25', '26', '27', '3', '31', '39', '40', '49', '50', '54', '55', '56', '57', '65', '66', '67', '9']
# Pair found for qid 66:
# Ngrams: name         Ngrams
# qid              66
# measure         map
# value      0.187105
# Name: 532, dtype: object
# BM25: name           BM25
# qid              66
# measure         map
# value      0.124202
# Name: 260, dtype: object
# ['11', '18', '19', '2', '20', '24', '25', '26', '27', '3', '31', '39', '40', '49', '50', '54', '55', '56', '57', '65', '66', '67', '9']
# Pair found for qid 67:
# Ngrams: name         Ngrams
# qid              67
# measure         map
# value      0.353342
# Name: 536, dtype: object
# BM25: name           BM25
# qid              67
# measure         map
# value      0.240052
# Name: 264, dtype: object
# ['11', '18', '19', '2', '20', '24', '25', '26', '27', '3', '31', '39', '40', '49', '50', '54', '55', '56', '57', '65', '66', '67', '9']
# Pair found for qid 9:
# Ngrams: name         Ngrams
# qid               9
# measure         map
# value      0.147781
# Name: 304, dtype: object
# BM25: name           BM25
# qid               9
# measure         map
# value      0.108192
# Name: 32, dtype: object
# ['11', '18', '19', '2', '20', '24', '25', '26', '27', '3', '31', '39', '40', '49', '50', '54', '55', '56', '57', '65', '66', '67', '9']

# %%
import pandas as pd

#print(pt_dataset.get_topics())
#valid_qids_normal = ['10', '18', '20', '28', '29', '3', '31', '33', '39', '4', '49', '51', '56', '62', '65', '68']
df = pd.DataFrame(pt_dataset.get_topics())
#print(df)

filtered_df = df[df['qid'].isin(valid_qids)]
# Printing the filtered DataFrame
print(filtered_df)
# Out:
# There are multiple query fields available: ('text', 'title', 'query', 'description', 'narrative'). To use with pyterrier, provide variant or modify dataframe to add query column.
#    qid                                               text  \
# 1    2           machine learning language identification
# 2    3                      social media detect self-harm
# 8    9                          Pseudo-relevance feedback
# 10  11            Algorithm acceleration with Nvidia CUDA
# 17  19         machine learning for more relevant results
# 18  20           Crawling websites using machine learning
# 22  24                       Limitations machine learning
# 23  25                          medicine related research
# 24  26                        Natural Language Processing
# 25  27                                graph based ranking
# 29  31   risks of information retrieval in social media ?
# 37  39      informational retrieval using neural networks
# 38  40                                 Query log analysis
# 47  49                             exhaustivity of index
# 48  50                                 query optimization
# 52  54         search engine optimization with query logs
# 53  55                                               BM25
# 54  56   What makes Natural Language Processing natural?
# 55  57      principle of a information retrieval indexing
# 63  65                  information in different language
# 64  66                           Abbreviations in queries
# 65  67                           lemmatization algorithms
# 67  18              Advancements in Information Retrieval
#
#                                                 title  \
# 1            machine learning language identification
# 2                       social media detect self-harm
# 8                           Pseudo-relevance feedback
# 10            Algorithm acceleration with Nvidia CUDA
# 17         machine learning for more relevant results
# 18           Crawling websites using machine learning
# 22                       Limitations machine learning
# 23                          medicine related research
# 24                        Natural Language Processing
# 25                                graph based ranking
# 29   risks of information retrieval in social media ?
# 37      informational retrieval using neural networks
# 38                                 Query log analysis
# 47                             exhaustivity of index
# 48                                 query optimization
# 52         search engine optimization with query logs
# 53                                               BM25
# 54   What makes Natural Language Processing natural?
# 55      principle of a information retrieval indexing
# 63                  information in different language
# 64                           Abbreviations in queries
# 65                           lemmatization algorithms
# 67              Advancements in Information Retrieval
#
#                                              query  \
# 1         machine learning language identification
# 2                    social media detect self harm
# 8                        pseudo relevance feedback
# 10         algorithm acceleration with nvidia cuda
# 17      machine learning for more relevant results
# 18        crawling websites using machine learning
# 22                    limitations machine learning
# 23                       medicine related research
# 24                     natural language processing
# 25                             graph based ranking
# 29  risks of information retrieval in social media
# 37   informational retrieval using neural networks
# 38                              query log analysis
# 47                           exhaustivity of index
# 48                              query optimization
# 52      search engine optimization with query logs
# 53                                            bm25
# 54  what makes natural language processing natural
# 55   principle of a information retrieval indexing
# 63               information in different language
# 64                        abbreviations in queries
# 65                        lemmatization algorithms
# 67           advancements in information retrieval
#
#                                           description  \
# 1   What papers are about machine learning for lan...
# 2   Which papers focus on how to recognize signs o...
# 8   How does pseudo-relevance feedback improve a q...
# 10  Developing new algorithms and improving the ex...
# 17  Which papers describe methods to find more rel...
# 18  Papers that describe how to use AI to crawl th...
# 22  Which papers describe the limitations of machi...
# 23           Papers that did research on medical data
# 24  Find papers that include the term natural lang...
# 25  Papers that are written about the method of gr...
# 29   What are the risks associated with using info...
# 37    Which papers include research on using neura...
# 38  Which papers include research on query log ana...
# 47  Documents that include explanations for what e...
# 48  How can I optimize my queries and what are the...
# 52  What documents explain the optimization of a s...
# 53                                How does BM25 work?
# 54  What is Natural Language Processing and why is...
# 55   How does indexing work in information retrieval?
# 63  Which papers cover Cross-language information ...
# 64  Which papers cover the handling of abbreviatio...
# 65       Which papers cover lemmatization algorithms?
# 67                                               None
#
#                                             narrative
# 1   Relevant papers include research on methods of...
# 2   Relevant papers include research on early dete...
# 8   Documents that specifically showcase how this ...
# 10  Relevant entries only include information abou...
# 17  Relevant papers describe one or more methods t...
# 18  Papers in this topic describe methods and algo...
# 22  Relevant papers describe the limitations of ma...
# 23  Find papers that did their research on medical...
# 24
# 25  Find papers that are about graph based ranking...
# 29  Relevant documents must discuss the risks of u...
# 37   Relevant papers discuss using neural networks...
# 38  Papers that involves the analysis of logs of u...
# 47  Relevant documents include the words index and...
# 48  Relevant optimizations for queries and their r...
# 52  Relevant documents include those referring to ...
# 53  Since BM25 is a very popular algorithm and I o...
# 54  Natural Language Processing is a model to proc...
# 55  Is the process of identifying and describing d...
# 63  Relevant papers cover concepts, that fall unde...
# 64  Relevant papers cover concepts, that deal with...
# 65  Relevant IR documents cover the topic of lemma...
# 67  Relevant texts contain Innovations or Advancem...
